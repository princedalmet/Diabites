# %% [markdown]
# <a href="https://colab.research.google.com/github/princedalmet/Diabites/blob/main/Diabitites.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('Diabetes.csv')
df.head(10)
# Out:
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224      F   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225      F   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6
# 7  421      34227      M   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8  670      34229      M   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 9  759      34230      F   32   3.6  28    4.0   3.8  2.0  2.4  3.8   1.0
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N
# 5  21.0     N
# 6  24.0     N
# 7  24.0     N
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
df['CLASS'].unique()
# Out:
# array(['N', 'N ', 'P', 'Y', 'Y '], dtype=object)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0    502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1    735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2    420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3    680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4    504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# ..   ...        ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...
# 995  200     454317      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6
# 996  671     876534      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4
# 997  669      87654      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1
# 998   99      24004      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0
# 999  248      24054      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7
#
#       BMI CLASS
# ...

# %%
df.isnull().sum()
# Out:
# ID           0
# No_Pation    0
# Gender       0
# AGE          0
# Urea         0
# Cr           0
# HbA1c        0
# Chol         0
# TG           0
# HDL          0
# LDL          0
# VLDL         0
# BMI          0
# CLASS        0
# dtype: int64

# %%
data = df.drop(['No_Pation'],axis='columns')
data.shape
# Out:
# (1000, 13)

# %%
data.info
# Out:
# <bound method DataFrame.info of       ID Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL   BMI CLASS
# 0    502      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 1    735      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6  23.0     N
# 2    420      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 3    680      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5  24.0     N
# 4    504      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4  21.0     N
# ..   ...    ...  ...   ...  ..    ...   ...  ...  ...  ...   ...   ...   ...
# 995  200      M   71  11.0  97    7.0   7.5  1.7  1.2  1.8   0.6  30.0     Y
# 996  671      M   31   3.0  60   12.3   4.1  2.2  0.7  2.4  15.4  37.2    Y
# 997  669      M   30   7.1  81    6.7   4.1  1.1  1.2  2.4   8.1  27.4    Y
# 998   99      M   38   5.8  59    6.7   5.3  2.0  1.6  2.9  14.0  40.5    Y
# 999  248      M   54   5.0  67    6.9   3.8  1.7  1.1  3.0   0.7  33.0    Y
#
# ...

# %%
data['AGE'].unique()
# Out:
# array([50, 26, 33, 45, 48, 43, 32, 31, 30, 49, 42, 39, 41, 44, 47, 36, 38,
#        46, 35, 40, 59, 51, 57, 63, 25, 60, 77, 54, 34, 55, 28, 56, 52, 69,
#        73, 61, 58, 53, 66, 68, 62, 64, 67, 70, 79, 76, 65, 75, 20, 71])

# %%
import seaborn as sns

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['AGE'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
plt.figure(figsize=(10,7))
chains=data['AGE'].value_counts()[0:100]
sns.barplot(x=chains,y=chains.index,palette='deep')
plt.title("Most age ")
plt.xlabel("Number of outlets")
# Out:
# Text(0.5, 0, 'Number of outlets')

# %%
x=data['Gender'].value_counts()
labels=['Male','Female']

# %%
data.sort_values(by='AGE').tail(5).plot.bar()

# %%
import plotly.express as px

# %%
px.scatter(data, x="AGE", y="Gender", color="CLASS", marginal_y="violin", marginal_x="box")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
px.histogram(data, x="AGE", y="Gender", color="CLASS")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data['Gender'].value_counts()
# Out:
# M    565
# F    434
# f      1
# Name: Gender, dtype: int64

# %%
data['Gender'] = data['Gender'].map({'M': 1, 'F': 0})
data['Gender'] = pd.to_numeric(data['Gender'], errors='coerce')

# %%
data['Gender'].value_counts()
# Out:
# 1.0    565
# 0.0    434
# Name: Gender, dtype: int64

# %%
data['CLASS'] = data['CLASS'].map({'N': 0, 'Y': 1,'P': 2})
data['CLASS'] = pd.to_numeric(data['CLASS'], errors='coerce')

# %%
data["CLASS"].value_counts()
# Out:
# 1.0    840
# 0.0    102
# 2.0     53
# Name: CLASS, dtype: int64

# %%
import missingno as msno

# %%
msno.bar(data)

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['Urea'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['Cr'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['HbA1c'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['Chol'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['TG'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['HDL'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['LDL'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['VLDL'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).

# %%
# Calc the diagnosis distribution
sns.set_style(style='whitegrid')
sns.distplot(data['BMI'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
